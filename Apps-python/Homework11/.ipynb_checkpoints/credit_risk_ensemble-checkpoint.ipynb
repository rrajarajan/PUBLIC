# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %%
# Integer Encoding - get_dummies()
df_encoded = pd.get_dummies(df, columns=["home_ownership", "verification_status", "loan_status", "pymnt_plan", "initial_list_status", "application_type", "hardship_flag", "debt_settlement_flag"])
df_encoded.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc   issue_d    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  Mar-2019  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  Mar-2019  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  Mar-2019  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  Mar-2019  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  Mar-2019  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  ...  verification_status_Verified  \
# 0             0.0       8.0      0.0  ...                             0
# 1             0.0      17.0      1.0  ...                             1
# 2             0.0       8.0      0.0  ...                             1
# 3             1.0      10.0      1.0  ...                             1
# 4             1.0      14.0      0.0  ...                             0
#
#    loan_status_high_risk  loan_status_low_risk  pymnt_plan_n  \
# 0                      0                     1             1
# 1                      0                     1             1
# 2                      0                     1             1
# 3                      0                     1             1
# 4                      0                     1             1
#
#    initial_list_status_f  initial_list_status_w  application_type_Individual  \
# 0                      0                      1                            1
# 1                      0                      1                            1
# 2                      0                      1                            1
# 3                      0                      1                            1
# 4                      0                      1                            1
#
#    application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# 0                           0                1                       1
# 1                           0                1                       1
# 2                           0                1                       1
# 3                           0                1                       1
# 4                           0                1                       1
#
# [5 rows x 94 columns]

# %%
# OR Integer Encoding - LabelEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# home_ownership column
le.fit(df["home_ownership"])
df["home_ownership"] = le.transform(df["home_ownership"])

# verification_status column
le.fit(df["verification_status"])
df["verification_status"] = le.transform(df["verification_status"])

# loan_status column
le.fit(df["loan_status"])
df["loan_status"] = le.transform(df["loan_status"])

# pymnt_plan column
le.fit(df["pymnt_plan"])
df["pymnt_plan"] = le.transform(df["pymnt_plan"])

# initial_list_status column
le.fit(df["initial_list_status"])
df["initial_list_status"] = le.transform(df["initial_list_status"])

# application_type column
le.fit(df["application_type"])
df["application_type"] = le.transform(df["application_type"])

# hardship_flag column
le.fit(df["hardship_flag"])
df["hardship_flag"] = le.transform(df["hardship_flag"])

# debt_settlement_flag column
le.fit(df["debt_settlement_flag"])
df["debt_settlement_flag"] = le.transform(df["debt_settlement_flag"])

# next_pymnt_d column
le.fit(df["next_pymnt_d"])
df["next_pymnt_d"] = le.transform(df["next_pymnt_d"])

# issue_d column
le.fit(df["issue_d"])
df["issue_d"] = le.transform(df["issue_d"])

df.head()
# Out:
#    loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35               3     66000.0
# 1    25000.0    0.2000       929.09               1    105000.0
# 2    20000.0    0.2000       529.88               1     56000.0
# 3    10000.0    0.1640       353.55               3     92000.0
# 4    22000.0    0.1474       520.39               1     52000.0
#
#    verification_status  issue_d  loan_status  pymnt_plan    dti  ...  \
# 0                    1        2            1           0  27.24  ...
# 1                    2        2            1           0  20.23  ...
# 2                    2        2            1           0  24.26  ...
# 3                    2        2            1           0  31.44  ...
# 4                    0        2            1           0  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          65687.0            38199.0          2000.0
# 1         271427.0            60641.0         41200.0
# 2          60644.0            45684.0          7500.0
# 3          99506.0            68784.0         19700.0
# 4         219750.0            25919.0         27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              0                     0
# 1                     49197.0              0                     0
# 2                     43144.0              0                     0
# 3                     76506.0              0                     0
# 4                     20000.0              0                     0
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.copy()

# Create our target
y = df["loan_status"]


X.drop("loan_status", axis=1, inplace=True)
X.head()
# Out:
#    loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35               3     66000.0
# 1    25000.0    0.2000       929.09               1    105000.0
# 2    20000.0    0.2000       529.88               1     56000.0
# 3    10000.0    0.1640       353.55               3     92000.0
# 4    22000.0    0.1474       520.39               1     52000.0
#
#    verification_status  issue_d  pymnt_plan    dti  delinq_2yrs  ...  \
# 0                    1        2           0  27.24          0.0  ...
# 1                    2        2           0  20.23          0.0  ...
# 2                    2        2           0  24.26          0.0  ...
# 3                    2        2           0  31.44          0.0  ...
# 4                    0        2           0  18.76          0.0  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          65687.0            38199.0          2000.0
# 1         271427.0            60641.0         41200.0
# 2          60644.0            45684.0          7500.0
# 3          99506.0            68784.0         19700.0
# 4         219750.0            25919.0         27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              0                     0
# 1                     49197.0              0                     0
# 2                     43144.0              0                     0
# 3                     76506.0              0                     0
# 4                     20000.0              0                     0
#
# [5 rows x 85 columns]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment  home_ownership    annual_inc  \
# count  68817.000000  68817.000000  68817.000000    68817.000000  6.881700e+04
# mean   16677.594562      0.127718    480.652863        1.812779  8.821371e+04
# std    10277.348590      0.048130    288.062432        0.941313  1.155800e+05
# min     1000.000000      0.060000     30.890000        0.000000  4.000000e+01
# 25%     9000.000000      0.088100    265.730000        1.000000  5.000000e+04
# 50%    15000.000000      0.118000    404.560000        1.000000  7.300000e+04
# 75%    24000.000000      0.155700    648.100000        3.000000  1.040000e+05
# max    40000.000000      0.308400   1676.230000        3.000000  8.797500e+06
#
#        verification_status       issue_d  pymnt_plan           dti  \
# count         68817.000000  68817.000000     68817.0  68817.000000
# mean              0.669994      0.805542         0.0     21.778153
# std               0.719105      0.714932         0.0     20.199244
# min               0.000000      0.000000         0.0      0.000000
# 25%               0.000000      0.000000         0.0     13.890000
# 50%               1.000000      1.000000         0.0     19.760000
# 75%               1.000000      1.000000         0.0     26.660000
# max               2.000000      2.000000         0.0    999.000000
#
#         delinq_2yrs  ...  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count  68817.000000  ...    68817.000000      68817.000000
# mean       0.217766  ...       95.057627         30.626217
# std        0.718367  ...        8.326426         33.631463
# min        0.000000  ...       20.000000          0.000000
# 25%        0.000000  ...       93.000000          0.000000
# 50%        0.000000  ...      100.000000         20.000000
# 75%        0.000000  ...      100.000000         50.000000
# max       18.000000  ...      100.000000        100.000000
#
#        pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# count          68817.000000    68817.0     6.881700e+04       6.881700e+04
# mean               0.125972        0.0     2.100332e+05       6.133843e+04
# std                0.336732        0.0     1.928088e+05       5.738798e+04
# min                0.000000        0.0     3.600000e+03       2.350000e+02
# 25%                0.000000        0.0     6.697700e+04       2.650300e+04
# 50%                0.000000        0.0     1.467100e+05       4.535700e+04
# 75%                0.000000        0.0     3.036400e+05       7.657000e+04
# max                4.000000        0.0     3.292782e+06       1.295455e+06
#
#        total_bc_limit  total_il_high_credit_limit  hardship_flag  \
# count    68817.000000                6.881700e+04        68817.0
# mean     29734.128558                5.572240e+04            0.0
# std      26795.394232                5.095845e+04            0.0
# min        100.000000                1.270000e+02            0.0
# 25%      11600.000000                2.288000e+04            0.0
# 50%      22100.000000                4.200000e+04            0.0
# 75%      39300.000000                7.249900e+04            0.0
# max     509400.000000                1.426964e+06            0.0
#
#        debt_settlement_flag
# count               68817.0
# mean                    0.0
# std                     0.0
# min                     0.0
# 25%                     0.0
# 50%                     0.0
# 75%                     0.0
# max                     0.0
#
# [8 rows x 85 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    68470
# 0      347
# Name: loan_status, dtype: int64

# %%
# Create our target
y = df["loan_status"].ravel()
y[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
from sklearn.model_selection import train_test_split

# Split the X and y into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training and testing data
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Perform combination sampling
from imblearn.combine import SMOTEENN

smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X_train_scaled, y_train)
Counter(y_resampled)

# %%
# Fit a logistic regression model to the combination sampled data
smoteenn_model = LogisticRegression(solver='lbfgs', random_state=1, max_iter=2000)
smoteenn_model.fit(X_resampled, y_resampled)

# %%
# Print the imbalanced classification report

y_pred = model.predict(X_test_scaled)
print(classification_report_imbalanced(y_test, y_pred))

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=1000, random_state=1)
brf_model = brf.fit(X_train_scaled, y_train)

# %%
# Calculated the balanced accuracy score
y_pred = brf_model.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5381133463245588

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   43,    49],
#        [ 6694, 10419]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.01      0.47      0.61      0.01      0.53      0.28        92
#           1       1.00      0.61      0.47      0.76      0.53      0.29     17113
#
# avg / total       0.99      0.61      0.47      0.75      0.53      0.29     17205

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = brf_model.feature_importances_

# %%
# List the features sorted in descending order by feature importance
sorted(zip(brf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.07431082120597778, 'total_rec_prncp'),
#  (0.06607471095801785, 'last_pymnt_amnt'),
#  (0.06187485136216447, 'total_pymnt_inv'),
#  (0.05853694152114562, 'total_pymnt'),
#  (0.05507912015713119, 'total_rec_int'),
#  (0.028934399960906035, 'int_rate'),
#  (0.021075769772655344, 'issue_d'),
#  (0.01828673780121855, 'dti'),
#  (0.017175230408813625, 'installment'),
#  (0.016933928847041375, 'mo_sin_old_rev_tl_op'),
#  (0.01691890278024448, 'annual_inc'),
#  (0.0167421134845241, 'max_bal_bc'),
#  (0.016292377369385404, 'mths_since_recent_inq'),
#  (0.016083253716117723, 'mo_sin_old_il_acct'),
#  (0.015682609907866588, 'out_prncp'),
#  (0.015223407092617285, 'bc_util'),
#  (0.015039016087448856, 'out_prncp_inv'),
#  (0.014817580841099718, 'tot_hi_cred_lim'),
#  (0.014817481902524408, 'bc_open_to_buy'),
#  (0.014545058675218152, 'revol_bal'),
#  (0.01412857987380057, 'total_bc_limit'),
#  (0.01390306301561219, 'il_util'),
#  (0.01341060415064303, 'total_rev_hi_lim'),
#  (0.013367133601004211, 'total_bal_il'),
#  (0.01322819758095374, 'avg_cur_bal'),
#  (0.01316642768303425, 'all_util'),
#  (0.013084470175703269, 'total_bal_ex_mort'),
#  (0.012949344059113063, 'tot_cur_bal'),
#  (0.01278392748321037, 'total_il_high_credit_limit'),
#  (0.012382787305213373, 'mths_since_rcnt_il'),
#  (0.011947670951973254, 'total_rec_late_fee'),
#  (0.011442719912405953, 'mths_since_recent_bc'),
#  (0.011248785932277967, 'loan_amnt'),
#  (0.0110458865285472, 'num_il_tl'),
#  (0.011011278577059361, 'total_acc'),
#  (0.01093813634994511, 'mo_sin_rcnt_tl'),
#  (0.010836719159914104, 'mo_sin_rcnt_rev_tl_op'),
#  (0.010413107351687635, 'num_rev_accts'),
#  (0.009408882325089834, 'open_acc'),
#  (0.00934826362562897, 'num_bc_tl'),
#  (0.00930223271654312, 'inq_last_6mths'),
#  (0.009216937063598494, 'num_sats'),
#  (0.008914263895254423, 'num_op_rev_tl'),
#  (0.00882705747757027, 'num_actv_rev_tl'),
#  (0.008824821863168068, 'acc_open_past_24mths'),
#  (0.008809737503672543, 'num_rev_tl_bal_gt_0'),
#  (0.008795599485709257, 'pct_tl_nvr_dlq'),
#  (0.008595054134160465, 'num_actv_bc_tl'),
#  (0.008591094958317195, 'inq_last_12m'),
#  (0.007570848671237836, 'open_il_24m'),
#  (0.0073900653998230075, 'num_bc_sats'),
#  (0.007159816065413544, 'inq_fi'),
#  (0.00699184414573063, 'num_tl_op_past_12m'),
#  (0.006843253556697467, 'total_cu_tl'),
#  (0.006684392684072448, 'percent_bc_gt_75'),
#  (0.0063962453805268375, 'open_act_il'),
#  (0.006267038486627219, 'open_rv_24m'),
#  (0.005821548021616438, 'mort_acc'),
#  (0.005544103814084399, 'next_pymnt_d'),
#  (0.005413145037659194, 'open_acc_6m'),
#  (0.004838275189593457, 'open_rv_12m'),
#  (0.0048305638626723315, 'verification_status'),
#  (0.00400389709806417, 'delinq_2yrs'),
#  (0.0037452922318979122, 'open_il_12m'),
#  (0.0034983464349751642, 'num_accts_ever_120_pd'),
#  (0.0030193739412462586, 'tot_coll_amt'),
#  (0.0023960525742134017, 'home_ownership'),
#  (0.0017871000812453195, 'pub_rec_bankruptcies'),
#  (0.0015463270498941026, 'pub_rec'),
#  (0.0012888454752612638, 'application_type'),
#  (0.0010356388251487679, 'initial_list_status'),
#  (0.0008851669658977811, 'num_tl_90g_dpd_24m'),
#  (0.0004841671861804192, 'collections_12_mths_ex_med'),
#  (0.00019155322729089597, 'chargeoff_within_12_mths'),
#  (0.0, 'tax_liens'),
#  (0.0, 'recoveries'),
#  (0.0, 'pymnt_plan'),
#  (0.0, 'policy_code'),
#  (0.0, 'num_tl_30dpd'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'hardship_flag'),
#  (0.0, 'delinq_amnt'),
#  (0.0, 'debt_settlement_flag'),
#  (0.0, 'collection_recovery_fee'),
#  (0.0, 'acc_now_delinq')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(brf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
# Train the data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5381133463245588

# %%
# Display the confusion matrix

y_pred = brf_model.predict(X_test_scaled)
confusion_matrix(y_test, y_pred)
# Out:
# array([[   43,    49],
#        [ 6694, 10419]])

# %%
# Print the imbalanced classification report

print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.01      0.47      0.61      0.01      0.53      0.28        92
#           1       1.00      0.61      0.47      0.76      0.53      0.29     17113
#
# avg / total       0.99      0.61      0.47      0.75      0.53      0.29     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     Both the Balanced Random Classifier and the easy Classifier had the same blanced score.
#
# 2. Which model had the best recall score?
#
#     Balanced Random Classifier had the bet recall score.
#
# 3. Which model had the best geometric mean score?
#
#     Balanced Random Classifier had the best geometric mean.
#
# 4. What are the top three features?
#
#     The top three features are total_rec_prncp, last_pymnt_amnt and total_pymnt_inv
